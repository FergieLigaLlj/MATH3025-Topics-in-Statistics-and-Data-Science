# %%
###    import numpy from the library
import numpy as np

# %%
def generate_random_number():
    while True:
        # Generate two uniform random numbers
        u1, u2 = np.random.uniform(), np.random.uniform()

        # Calculate x and the acceptance probability
        x = np.sign(u1 - 0.5) * 5 * np.log(1 / (1 - 2 * abs(u1 - 0.5)))
        p = np.exp(-abs(x) / 5)

        # Accept or reject the sample
        if u2 <= p:
            return x

# Generate 1000 random numbers
n = 1000
random_numbers = np.array([generate_random_number() for _ in range(n)])
random_numbers = random_numbers.T

print(random_numbers)
# Out:
# [ 4.23932659e+00 -7.12229201e+00  3.43353843e-01 -7.45284141e-01
#   6.26409603e-03 -2.77138909e+00  9.70632294e-01 -1.40246262e+00
#   2.44059437e-01 -6.67588910e+00 -2.82207597e+00  5.01322415e+00
#   1.42349988e+00 -1.14222041e+00 -3.22045653e+00 -4.15726233e+00
#  -3.68332985e-01  5.69362189e+00  8.51241242e-01 -1.69364202e-01
#   8.46257494e-01 -2.13065131e+00  1.58215669e+00  1.27731698e+00
#  -1.12356317e-01 -9.66496335e+00 -1.92535665e+00 -2.45425946e+00
#   9.75955589e-01 -2.59822816e-01 -3.44664349e+00 -3.25320454e+00
#  -3.79511589e+00  1.59774206e+00  1.13332856e+00 -2.22791531e-01
#  -6.77928941e-01  3.03760325e+00 -5.13326634e+00 -2.64344995e+00
#  -1.49850999e-01  2.61879135e+00 -2.22969044e-01 -9.37082979e-02
#   3.74434937e+00 -2.90985948e+00 -2.42801677e+00 -3.89470340e+00
#  -5.37367924e+00  3.87510557e+00 -1.06852174e+00  6.91326868e+00
#   2.14444186e+00 -3.52606986e-01 -2.01857748e+00  3.06668536e+00
# ...
